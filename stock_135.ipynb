# %% [markdown]
# <a href="https://colab.research.google.com/github/UNT-CSCE-Projects/UNT-CSE-SpaceshipTitanic/blob/main/stock_135.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('new_data_project.csv')
data.head(5)
# Out:
#    stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0       135      191                  0      1311786.88
# 1       135      191                 10      1310833.09
# 2       135      191                 20      1308925.51
# 3       135      191                 30      1307971.72
# 4       135      191                 40      1300369.88
#
#    imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                        1         0.998198    1467610.33        NaN
# 1                        1         1.000305    1467610.33        NaN
# 2                        1         1.003115    1467610.33        NaN
# 3                        1         1.004520    1467610.33        NaN
# 4                        1         1.007330    1467610.33        NaN
#
#    near_price  bid_price  bid_size  ask_price  ask_size       wap     target  \
# 0         NaN   0.999603  18499.00   1.000305  14240.00  1.000000  23.020506
# ...

# %%
train = data.drop(axis='columns', columns=['stock_id', 'date_id','seconds_in_bucket','imbalance_size','imbalance_buy_sell_flag', 'reference_price','matched_size','far_price', 'near_price','bid_price','bid_size','ask_price','ask_size','wap','row_id'])
train = train.set_index('time_id')

# %%
start = 0 # start of day 1
end = 55 # end of day 1 -> 6(one reading each 10 seconds) * 9 minutes
start = 0
end = 55
ttrain=train[0:55]
ttrain = ttrain.reset_index(drop=True)
ttrain
# Out:
#        target
# 0   23.020506
# 1   27.409792
# 2   23.789406
# 3   11.769533
# 4  -19.400120
# 5  -25.249720
# 6  -28.780102
# 7  -22.950172
# 8  -36.110283
# 9  -14.140010
# 10  -0.939965
# 11   5.049705
# 12 -16.390085
# 13  -5.369782
# 14 -10.970235
# 15 -29.789806
# 16 -29.019714
# 17 -31.549930
# 18  14.419556
# 19   9.059906
# 20  26.119947
# 21  38.150550
# 22  65.729614
# 23  38.299560
# 24  36.129950
# 25  30.930042
# 26  20.949840
# 27   7.259846
# 28 -25.050045
# 29   2.520084
# 30 -15.900135
# 31 -22.829771
# 32 -16.649961
# 33  -4.739761
# 34  -1.739860
# 35 -11.529922
# 36  -9.779930
# 37   0.619888
# 38  -2.380014
# 39 -10.539889
# 40 -17.480255
# 41  -9.329915
# 42  -5.829930
# 43   2.959967
# 44   2.419949
# 45  23.419857
# 46  36.829712
# 47  52.859783
# 48  61.459540
# 49  18.140078
# 50  24.830103
# 51   6.309748
# 52  -4.749894
# 53   6.170273
# 54  11.099577

# %%
new_data['target']=ttrain

# %%
new_data
# Out:
#              Timestamps     target
# 0   2015-01-01 15:50:00  23.020506
# 1   2015-01-01 15:50:10  27.409792
# 2   2015-01-01 15:50:20  23.789406
# 3   2015-01-01 15:50:30  11.769533
# 4   2015-01-01 15:50:40 -19.400120
# 5   2015-01-01 15:50:50 -25.249720
# 6   2015-01-01 15:51:00 -28.780102
# 7   2015-01-01 15:51:10 -22.950172
# 8   2015-01-01 15:51:20 -36.110283
# 9   2015-01-01 15:51:30 -14.140010
# 10  2015-01-01 15:51:40  -0.939965
# 11  2015-01-01 15:51:50   5.049705
# 12  2015-01-01 15:52:00 -16.390085
# 13  2015-01-01 15:52:10  -5.369782
# 14  2015-01-01 15:52:20 -10.970235
# 15  2015-01-01 15:52:30 -29.789806
# 16  2015-01-01 15:52:40 -29.019714
# 17  2015-01-01 15:52:50 -31.549930
# 18  2015-01-01 15:53:00  14.419556
# 19  2015-01-01 15:53:10   9.059906
# 20  2015-01-01 15:53:20  26.119947
# 21  2015-01-01 15:53:30  38.150550
# 22  2015-01-01 15:53:40  65.729614
# 23  2015-01-01 15:53:50  38.299560
# 24  2015-01-01 15:54:00  36.129950
# 25  2015-01-01 15:54:10  30.930042
# ...

# %%
ttrain['target']
# Out:
# time_id
# 10505    23.020506
# 10506    27.409792
# 10507    23.789406
# 10508    11.769533
# 10509   -19.400120
# 10510   -25.249720
# 10511   -28.780102
# 10512   -22.950172
# 10513   -36.110283
# 10514   -14.140010
# 10515    -0.939965
# 10516     5.049705
# 10517   -16.390085
# 10518    -5.369782
# 10519   -10.970235
# 10520   -29.789806
# 10521   -29.019714
# 10522   -31.549930
# 10523    14.419556
# 10524     9.059906
# 10525    26.119947
# 10526    38.150550
# 10527    65.729614
# 10528    38.299560
# 10529    36.129950
# 10530    30.930042
# 10531    20.949840
# 10532     7.259846
# 10533   -25.050045
# 10534     2.520084
# 10535   -15.900135
# 10536   -22.829771
# 10537   -16.649961
# 10538    -4.739761
# 10539    -1.739860
# 10540   -11.529922
# 10541    -9.779930
# 10542     0.619888
# 10543    -2.380014
# 10544   -10.539889
# 10545   -17.480255
# 10546    -9.329915
# 10547    -5.829930
# 10548     2.959967
# 10549     2.419949
# 10550    23.419857
# 10551    36.829712
# ...

# %%
import pandas as pd
from datetime import datetime, timedelta

start_time = datetime(2015, 1, 1, 15, 50, 0)
end_time = datetime(2015, 1, 1, 15, 58, 50)


interval = timedelta(seconds=10)

date_time = []
#%Y-%m-%d %H:%M:%S
for i in range(0, int((end_time - start_time).total_seconds()) + 1, 10):
    now = start_time + timedelta(seconds=i)
    date_time.append(now.strftime('%Y-%m-%d %H:%M:%S'))




new_data = pd.DataFrame({'Timestamps': date_time})
print(new_data)
# Out:
#              Timestamps
# 0   2015-01-01 15:50:00
# 1   2015-01-01 15:50:10
# 2   2015-01-01 15:50:20
# 3   2015-01-01 15:50:30
# 4   2015-01-01 15:50:40
# 5   2015-01-01 15:50:50
# 6   2015-01-01 15:51:00
# 7   2015-01-01 15:51:10
# 8   2015-01-01 15:51:20
# 9   2015-01-01 15:51:30
# 10  2015-01-01 15:51:40
# 11  2015-01-01 15:51:50
# 12  2015-01-01 15:52:00
# 13  2015-01-01 15:52:10
# 14  2015-01-01 15:52:20
# 15  2015-01-01 15:52:30
# 16  2015-01-01 15:52:40
# 17  2015-01-01 15:52:50
# 18  2015-01-01 15:53:00
# 19  2015-01-01 15:53:10
# 20  2015-01-01 15:53:20
# 21  2015-01-01 15:53:30
# 22  2015-01-01 15:53:40
# 23  2015-01-01 15:53:50
# 24  2015-01-01 15:54:00
# 25  2015-01-01 15:54:10
# 26  2015-01-01 15:54:20
# 27  2015-01-01 15:54:30
# 28  2015-01-01 15:54:40
# 29  2015-01-01 15:54:50
# 30  2015-01-01 15:55:00
# 31  2015-01-01 15:55:10
# 32  2015-01-01 15:55:20
# 33  2015-01-01 15:55:30
# 34  2015-01-01 15:55:40
# 35  2015-01-01 15:55:50
# 36  2015-01-01 15:56:00
# ...

# %%
new_data['target']=ttrain

# %%
new_data
# Out:
#              Timestamps     target
# 0   2015-01-01 15:50:00  23.020506
# 1   2015-01-01 15:50:10  27.409792
# 2   2015-01-01 15:50:20  23.789406
# 3   2015-01-01 15:50:30  11.769533
# 4   2015-01-01 15:50:40 -19.400120
# 5   2015-01-01 15:50:50 -25.249720
# 6   2015-01-01 15:51:00 -28.780102
# 7   2015-01-01 15:51:10 -22.950172
# 8   2015-01-01 15:51:20 -36.110283
# 9   2015-01-01 15:51:30 -14.140010
# 10  2015-01-01 15:51:40  -0.939965
# 11  2015-01-01 15:51:50   5.049705
# 12  2015-01-01 15:52:00 -16.390085
# 13  2015-01-01 15:52:10  -5.369782
# 14  2015-01-01 15:52:20 -10.970235
# 15  2015-01-01 15:52:30 -29.789806
# 16  2015-01-01 15:52:40 -29.019714
# 17  2015-01-01 15:52:50 -31.549930
# 18  2015-01-01 15:53:00  14.419556
# 19  2015-01-01 15:53:10   9.059906
# 20  2015-01-01 15:53:20  26.119947
# 21  2015-01-01 15:53:30  38.150550
# 22  2015-01-01 15:53:40  65.729614
# 23  2015-01-01 15:53:50  38.299560
# 24  2015-01-01 15:54:00  36.129950
# 25  2015-01-01 15:54:10  30.930042
# ...

# %%
data.isna().sum()
# Out:
# stock_id                      0
# date_id                       0
# seconds_in_bucket             0
# imbalance_size                0
# imbalance_buy_sell_flag       0
# reference_price               0
# matched_size                  0
# far_price                  8815
# near_price                 8700
# bid_price                     0
# bid_size                      0
# ask_price                     0
# ask_size                      0
# wap                           0
# target                        0
# time_id                       0
# row_id                        0
# dtype: int64

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Sample data for one month
data = pd.DataFrame({
    'ds': new_data['Timestamps'],
    'y': new_data['target']
})

# Adding holidays (optional)
'''
holidays = pd.DataFrame({
    'holiday': 'custom_holiday',
    'ds': pd.to_datetime(['2023-11-25']),
    'lower_window': 0,
    'upper_window': 0,
})
'''
# Create and fit the model
model = Prophet()#holidays=holidays)
model.fit(data)

# Create a dataframe with future dates for prediction
future = model.make_future_dataframe(periods=7)  # Add 7 days for future predictions

# Make predictions
forecast = model.predict(future)

# Plot the results
fig = model.plot(forecast)
plt.show()
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6_s0gn0u/zbalfaqf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6_s0gn0u/skclep_u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45949', 'data', 'file=/tmp/tmp6_s0gn0u/zbalfaqf.json', 'init=/tmp/tmp6_s0gn0u/skclep_u.json', 'output', 'file=/tmp/tmp6_s0gn0u/prophet_modelug_w_0vc/prophet_model-20231130050640.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:06:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# ...

# %%
df
# Out:
#      ds          y
# 0   NaN  23.020506
# 1   NaN  27.409792
# 2   NaN  23.789406
# 3   NaN  11.769533
# 4   NaN -19.400120
# 5   NaN -25.249720
# 6   NaN -28.780102
# 7   NaN -22.950172
# 8   NaN -36.110283
# 9   NaN -14.140010
# 10  NaN  -0.939965
# 11  NaN   5.049705
# 12  NaN -16.390085
# 13  NaN  -5.369782
# 14  NaN -10.970235
# 15  NaN -29.789806
# 16  NaN -29.019714
# 17  NaN -31.549930
# 18  NaN  14.419556
# 19  NaN   9.059906
# 20  NaN  26.119947
# 21  NaN  38.150550
# 22  NaN  65.729614
# 23  NaN  38.299560
# 24  NaN  36.129950
# 25  NaN  30.930042
# 26  NaN  20.949840
# 27  NaN   7.259846
# 28  NaN -25.050045
# 29  NaN   2.520084
# 30  NaN -15.900135
# 31  NaN -22.829771
# 32  NaN -16.649961
# 33  NaN  -4.739761
# 34  NaN  -1.739860
# 35  NaN -11.529922
# 36  NaN  -9.779930
# 37  NaN   0.619888
# 38  NaN  -2.380014
# 39  NaN -10.539889
# 40  NaN -17.480255
# 41  NaN  -9.329915
# 42  NaN  -5.829930
# 43  NaN   2.959967
# 44  NaN   2.419949
# 45  NaN  23.419857
# ...

# %%
df['ds']=new_data['Timestamps']
df
# Out:
#                      ds          y
# 0   2015-01-01 15:50:00  23.020506
# 1   2015-01-01 15:50:10  27.409792
# 2   2015-01-01 15:50:20  23.789406
# 3   2015-01-01 15:50:30  11.769533
# 4   2015-01-01 15:50:40 -19.400120
# 5   2015-01-01 15:50:50 -25.249720
# 6   2015-01-01 15:51:00 -28.780102
# 7   2015-01-01 15:51:10 -22.950172
# 8   2015-01-01 15:51:20 -36.110283
# 9   2015-01-01 15:51:30 -14.140010
# 10  2015-01-01 15:51:40  -0.939965
# 11  2015-01-01 15:51:50   5.049705
# 12  2015-01-01 15:52:00 -16.390085
# 13  2015-01-01 15:52:10  -5.369782
# 14  2015-01-01 15:52:20 -10.970235
# 15  2015-01-01 15:52:30 -29.789806
# 16  2015-01-01 15:52:40 -29.019714
# 17  2015-01-01 15:52:50 -31.549930
# 18  2015-01-01 15:53:00  14.419556
# 19  2015-01-01 15:53:10   9.059906
# 20  2015-01-01 15:53:20  26.119947
# 21  2015-01-01 15:53:30  38.150550
# 22  2015-01-01 15:53:40  65.729614
# 23  2015-01-01 15:53:50  38.299560
# 24  2015-01-01 15:54:00  36.129950
# 25  2015-01-01 15:54:10  30.930042
# ...

# %%
fig = model.plot(forecast)
plt.show()

# %%
import pandas as pd
from prophet import Prophet

# Create a sample dataframe with timestamps at 9-minute intervals

date_rng = pd.date_range(start='2015-01-01 15:50:00', end='2015-01-01 15:58:50', freq='470T')
df['ds']=new_data['Timestamps']
df = pd.DataFrame(date_rng,columns=['ds'])
df['y'] = new_data['target']  # Sample data for the y column
print(df)

# Create and fit the Prophet model
model = Prophet()
model.fit(df)

# Create a dataframe for future timestamps (next day 2 minutes)
future = model.make_future_dataframe(periods=2, freq='T')

# Make predictions
forecast = model.predict(future)

# Display the forecast
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
#                    ds          y
# 0 2015-01-01 15:50:00  23.020506
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-b0d1f3df6f29> in <cell line: 14>()
#      12 # Create and fit the Prophet model
#      13 model = Prophet()
# ---> 14 model.fit(df)
#      15
#      16 # Create a dataframe for future timestamps (next day 2 minutes)
#
# /usr/local/lib/python3.10/dist-packages/prophet/forecaster.py in fit(self, df, **kwargs)
#    1215                             'Instantiate a new object.')
#    1216
# -> 1217         model_inputs = self.preprocess(df, **kwargs)
#    1218         initial_params = self.calculate_initial_params(model_inputs.K)
#    1219
#
# /usr/local/lib/python3.10/dist-packages/prophet/forecaster.py in preprocess(self, df, **kwargs)
#    1130         history = df[df['y'].notnull()].copy()
#    1131         if history.shape[0] < 2:
# ...

# %%
from datetime import datetime, timedelta, time

start_date = datetime(2015, 1, 1)
end_date = datetime(2015, 12, 31)
start_time = time(15, 51, 0)
end_time = time(15, 58, 50)
interval = timedelta(seconds=10)

current_datetime = datetime.combine(start_date, start_time)

while current_datetime <= datetime.combine(end_date, end_time):
    print(current_datetime.strftime('%Y-%m-%d %H:%M:%S'))
    current_datetime += interval
# Out:
# Streaming output truncated to the last 5000 lines.
# 2015-12-31 02:05:40
# 2015-12-31 02:05:50
# 2015-12-31 02:06:00
# 2015-12-31 02:06:10
# 2015-12-31 02:06:20
# 2015-12-31 02:06:30
# 2015-12-31 02:06:40
# 2015-12-31 02:06:50
# 2015-12-31 02:07:00
# 2015-12-31 02:07:10
# 2015-12-31 02:07:20
# 2015-12-31 02:07:30
# 2015-12-31 02:07:40
# 2015-12-31 02:07:50
# 2015-12-31 02:08:00
# 2015-12-31 02:08:10
# 2015-12-31 02:08:20
# 2015-12-31 02:08:30
# 2015-12-31 02:08:40
# 2015-12-31 02:08:50
# 2015-12-31 02:09:00
# 2015-12-31 02:09:10
# 2015-12-31 02:09:20
# 2015-12-31 02:09:30
# 2015-12-31 02:09:40
# 2015-12-31 02:09:50
# 2015-12-31 02:10:00
# 2015-12-31 02:10:10
# 2015-12-31 02:10:20
# 2015-12-31 02:10:30
# 2015-12-31 02:10:40
# 2015-12-31 02:10:50
# 2015-12-31 02:11:00
# 2015-12-31 02:11:10
# 2015-12-31 02:11:20
# 2015-12-31 02:11:30
# 2015-12-31 02:11:40
# 2015-12-31 02:11:50
# 2015-12-31 02:12:00
# 2015-12-31 02:12:10
# 2015-12-31 02:12:20
# 2015-12-31 02:12:30
# 2015-12-31 02:12:40
# ...

# %%
count=0
m=[]
for i in f :
  print(data[data['stock_id'] == i].size)
  count=count+1
print(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c9012eb9f03f> in <cell line: 3>()
#       1 count=0
#       2 m=[]
# ----> 3 for i in f :
#       4   print(data[data['stock_id'] == i].size)
#       5   count=count+1
#
# NameError: name 'f' is not defined

# %%
print(data[data['stock_id'] ==135 ].size)
datap=data[data['stock_id'] ==135 ]
datap.isna().any()
# Out:
# 271150
# stock_id                   False
# date_id                    False
# seconds_in_bucket          False
# imbalance_size             False
# imbalance_buy_sell_flag    False
# reference_price            False
# matched_size               False
# far_price                   True
# near_price                  True
# bid_price                  False
# bid_size                   False
# ask_price                  False
# ask_size                   False
# wap                        False
# target                     False
# time_id                    False
# row_id                     False
# dtype: bool

# %%
output_csv_file = "new_data_project.csv"

# Use the to_csv method to save the DataFrame to the new CSV file
datap.to_csv(output_csv_file, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b1eaa8dc6c6a> in <cell line: 4>()
#       2
#       3 # Use the to_csv method to save the DataFrame to the new CSV file
# ----> 4 datap.to_csv(output_csv_file, index=False)
#
# NameError: name 'datap' is not defined

# %%
temporal_features = ['date_id', 'seconds_in_bucket']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,12))
plt.plot(data['date_id'], data['target'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13,8))
plt.plot(data['time_id'], data['target'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your time series data into a pandas DataFrame
# For example, if your data is in a CSV file, you can use pd.read_csv('your_data.csv')

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(data['date_id'],data['target'], label='Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Data')

# Calculate rolling statistics (e.g., moving average)
rolling_mean = data['target'].rolling(window=12).mean()
rolling_std = data['target'].rolling(window=12).std()

# Plot rolling statistics
plt.plot(data['date_id'], rolling_mean, label='Rolling Mean')
plt.plot(data['date_id'], rolling_std, label='Rolling Std')

plt.legend()
plt.show()

# Perform Augmented Dickey-Fuller test
from statsmodels.tsa.stattools import adfuller

result = adfuller(data['target'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])

if result[1] <= 0.05:
    print('The time series is stationary.')
else:
    print('The time series is not stationary.')
# Out:
# ADF Statistic: -25.732757553351526
# p-value: 0.0
# The time series is stationary.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your time series data into a pandas DataFrame
# For example, if your data is in a CSV file, you can use pd.read_csv('your_data.csv')

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(data['time_id'],data['target'], label='Time Series Data')
plt.xlabel('time')
plt.ylabel('Value')
plt.title('Time Series Data')

# Calculate rolling statistics (e.g., moving average)
rolling_mean = data['target'].rolling(window=12).mean()
rolling_std = data['target'].rolling(window=12).std()

# Plot rolling statistics
plt.plot(data['time_id'], rolling_mean, label='Rolling Mean')
plt.plot(data['time_id'], rolling_std, label='Rolling Std')

plt.legend()
plt.show()

# Perform Augmented Dickey-Fuller test
from statsmodels.tsa.stattools import adfuller

result = adfuller(data['target'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])

if result[1] <= 0.05:
    print('The time series is stationary.')
else:
    print('The time series is not stationary.')
# Out:
# ADF Statistic: -25.732757553351526
# p-value: 0.0
# The time series is stationary.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# Load your time series data into a pandas DataFrame
# For example, if your data is in a CSV file, you can use pd.read_csv('your_data.csv')

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(data['time_id'], data['target'], label='Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Data')

# Calculate rolling statistics (e.g., moving average)
rolling_mean = data['target'].rolling(window=12).mean()
rolling_std = data['target'].rolling(window=12).std()

# Plot rolling statistics
plt.plot(data['time_id'], rolling_mean, label='Rolling Mean')
plt.plot(data['time_id'], rolling_std, label='Rolling Std')

plt.legend()
plt.show()

# Perform Augmented Dickey-Fuller test
result = adfuller(data['target'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])

if result[1] <= 0.05:
    print('The time series is stationary.')
else:
    print('The time series is not stationary.')
# Out:
# ADF Statistic: -25.732757553351526
# p-value: 0.0
# The time series is stationary.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller

# Load your time series data into a pandas DataFrame
# Replace 'date_column' and 'value_column' with your own column names
# For example, if your data is in a CSV file, you can use pd.read_csv('your_data.csv')

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(data['time_id'],data['target'], label='Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Data')

# Check for stationarity using ADF test
result = adfuller(data['target'])
if result[1] <= 0.05:
    print('The time series is stationary.')
else:
    print('The time series is not stationary. Please make it stationary before fitting an ARIMA model.')
    # You can use differencing to make it stationary.

# Fit an ARIMA model
# The order of the ARIMA model is represented as (p, d, q), where:
# p: The order of the autoregressive component.
# d: The order of differencing required to make the series stationary.
# q: The order of the moving average component.

# Example: Fit an ARIMA(1, 1, 1) model
p, d, q = 1, 1, 1
model = ARIMA(data['target'], order=(p, d, q))
results = model.fit(disp=-1)

# Print model summary
print(results.summary())

# Plot the fitted values
plt.figure(figsize=(12, 6))
plt.plot(data['time_id'], data['target'], label='Original Data')
plt.plot(data['time_id'], results.fittedvalues, color='red', label='Fitted Values')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('ARIMA Fit')
plt.legend()
plt.show()
# Out:
# The time series is stationary.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-13-be8ee6ae0cf3> in <cell line: 34>()
#      32 # Example: Fit an ARIMA(1, 1, 1) model
#      33 p, d, q = 1, 1, 1
# ---> 34 model = ARIMA(data['target'], order=(p, d, q))
#      35 results = model.fit(disp=-1)
#      36
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# ...

# %%
pip install statsmodels

# %%
df

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Generate example time series data

# Create a pandas DataFrame
df = pd.DataFrame(data['date_id'])
df['Value']= data['target']
print(df)
# Plot the time series
plt.plot(df['Value'])
plt.title('Example Time Series Data')
plt.show()

# Plot the autocorrelation and partial autocorrelation functions
plot_acf(df['Value'], lags=20, title='ACF')
plot_pacf(df['Value'], lags=20, title='PACF')
plt.show()

# Define the SARIMA model
order = (1, 1, 1)  # ARIMA order
seasonal_order = (1, 1, 1, 12)  # Seasonal order (for example, with a yearly seasonality)

# Fit the SARIMA model
sarima_model = SARIMAX(df['Value'], order=order, seasonal_order=seasonal_order)
sarima_result = sarima_model.fit(disp=False)

# Print the model summary
print(sarima_result.summary())

# Plot the residuals
sarima_result.plot_diagnostics()
plt.show()
# Out:
#        date_id      Value
# 0          191  23.020506
# 1          191  27.409792
# 2          191  23.789406
# 3          191  11.769533
# 4          191 -19.400120
# ...        ...        ...
# 15945      480   1.339912
# 15946      480   3.590584
# 15947      480   8.499622
# 15948      480   3.449917
# 15949      480   2.640486
#
# [15950 rows x 2 columns]
#                                      SARIMAX Results
# ...
# Dep. Variable:                              Value   No. Observations:                15950
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood              -54513.821
# Date:                            Sat, 18 Nov 2023   AIC                         109037.641
# Time:                                    00:16:26   BIC                         109076.023
# Sample:                                         0   HQIC                        109050.338
#                                           - 15950
# Covariance Type:                              opg
# ...

# %%
n = 15950
t = np.arange(n)
forecast_steps = 20
forecast = sarima_result.get_forecast(steps=forecast_steps)
forecast_index = np.arange(n, n + forecast_steps)
plt.figure(figsize=(12, 6))
# Plot the original time series and the forecast
plt.plot(t, df['Value'], label='Original')
plt.plot(forecast_index, forecast.predicted_mean, color='red', label='Forecast')
plt.fill_between(forecast_index, forecast.conf_int()['lower Value'], forecast.conf_int()['upper Value'], color='pink', alpha=0.3, label='Confidence Interval')
plt.legend()
plt.title('SARIMA Forecast')
plt.show()

# %%
df

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Generate example time series data

# Create a pandas DataFrame
df = pd.DataFrame(data['time_id'])
df['Value']= data['target']
print(df)
# Plot the time series
plt.plot(df['time_id'],df['Value'])
plt.title('continous time series data')
plt.show()

# Plot the autocorrelation and partial autocorrelation functions
plot_acf(df['Value'], lags=40, title='ACF')
plot_pacf(df['Value'], lags=40, title='PACF')
plt.show()

# Define the SARIMA model
order = (1, 1, 1)  # ARIMA order
seasonal_order = (1, 1, 1, 12)  # Seasonal order (for example, with a yearly seasonality)

# Fit the SARIMA model
sarima_model = SARIMAX(df['Value'], order=order, seasonal_order=seasonal_order)
sarima_result = sarima_model.fit(disp=False)

# Print the model summary
print(sarima_result.summary())

# Plot the residuals
sarima_result.plot_diagnostics()
plt.show()

# %%
n = 15950
t = np.arange(n)
forecast_steps = 20
forecast = sarima_result.get_forecast(steps=forecast_steps)
forecast_index = np.arange(n, n + forecast_steps)
plt.figure(figsize=(12, 6))
# Plot the original time series and the forecast
plt.plot(t, df['Value'], label='Original')
plt.plot(forecast_index, forecast.predicted_mean, color='red', label='Forecast')
plt.fill_between(forecast_index, forecast.conf_int()['lower Value'], forecast.conf_int()['upper Value'], color='pink', alpha=0.3, label='Confidence Interval')
plt.legend()
plt.title('SARIMA Forecast')
plt.show()

# %%
sarima = SARIMAX(df['Value'],
                order=(1,1,1),
                seasonal_order=(1,1,0,12))
predictions = sarima.fit().predict()

# %%
plt.figure(figsize=(16,4))
plt.plot(predictions, label="Predicted",color='red')
plt.plot(df['Value'],label='Actual')

plt.ylabel('Sales', fontsize=16)
plt.legend()

# %%
data['time_id'] = pd.to_datetime(data['time_id'])
data = data.set_index('time_id')

# Split your data into training and testing sets
train_size = int(len(df) * 0.8)
train, test = df.iloc[:train_size], df.iloc[train_size:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_id'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import statsmodels.api as sm
sarima_model = sm.tsa.SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_result = sarima_model.fit(disp=False)

# Make predictions on the test set
predictions = sarima_result.get_forecast(steps=len(test))
predicted_mean = predictions.predicted_mean
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
predictions = sarima_result.get_forecast(steps=len(test))
predicted_mean = predictions.predicted_mean

# Evaluate the model using metrics
mae = mean_absolute_error(test, predicted_mean)
mse = mean_squared_error(test, predicted_mean)
rmse = np.sqrt(mse)

# Print the metrics
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Mean Absolute Error (MAE): 0.25391874968594735
# Mean Squared Error (MSE): 0.08732899331239206
# Root Mean Squared Error (RMSE): 0.2955147937284901
