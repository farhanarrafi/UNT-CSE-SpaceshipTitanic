# %% [markdown]
# <a href="https://colab.research.google.com/github/UNT-CSCE-Projects/UNT-CSE-SpaceshipTitanic/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('new_data_project.csv')
data.head(5)
# Out:
#    stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0       135      191                  0      1311786.88
# 1       135      191                 10      1310833.09
# 2       135      191                 20      1308925.51
# 3       135      191                 30      1307971.72
# 4       135      191                 40      1300369.88
#
#    imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                        1         0.998198    1467610.33        NaN
# 1                        1         1.000305    1467610.33        NaN
# 2                        1         1.003115    1467610.33        NaN
# 3                        1         1.004520    1467610.33        NaN
# 4                        1         1.007330    1467610.33        NaN
#
#    near_price  bid_price  bid_size  ask_price  ask_size       wap     target  \
# 0         NaN   0.999603  18499.00   1.000305  14240.00  1.000000  23.020506
# ...

# %%
# Out:
# [<bound method Series.unique of 0        191
#  1        191
#  2        191
#  3        191
#  4        191
#          ...
#  15945    480
#  15946    480
#  15947    480
#  15948    480
#  15949    480
#  Name: date_id, Length: 15950, dtype: int64>]

# %%
data.isna().sum()
# Out:
# stock_id                      0
# date_id                       0
# seconds_in_bucket             0
# imbalance_size                0
# imbalance_buy_sell_flag       0
# reference_price               0
# matched_size                  0
# far_price                  8815
# near_price                 8700
# bid_price                     0
# bid_size                      0
# ask_price                     0
# ask_size                      0
# wap                           0
# target                        0
# time_id                       0
# row_id                        0
# dtype: int64

# %%
8815+8700
# Out:
# 17515

# %%
count=0
m=[]
for i in f :
  print(data[data['stock_id'] == i].size)
  count=count+1
print(count)
# Out:
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 448800
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 448800
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# 449735
# ...

# %%
print(data[data['stock_id'] ==135 ].size)
datap=data[data['stock_id'] ==135 ]
datap.isna().any()
# Out:
# 271150
# stock_id                   False
# date_id                    False
# seconds_in_bucket          False
# imbalance_size             False
# imbalance_buy_sell_flag    False
# reference_price            False
# matched_size               False
# far_price                   True
# near_price                  True
# bid_price                  False
# bid_size                   False
# ask_price                  False
# ask_size                   False
# wap                        False
# target                     False
# time_id                    False
# row_id                     False
# dtype: bool

# %%
output_csv_file = "new_data_project.csv"

# Use the to_csv method to save the DataFrame to the new CSV file
datap.to_csv(output_csv_file, index=False)

# %%
temporal_features = ['date_id', 'seconds_in_bucket']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,12))
plt.plot(data['date_id'], data['target'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13,8))
plt.plot(data['time_id'], data['target'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your time series data into a pandas DataFrame
# For example, if your data is in a CSV file, you can use pd.read_csv('your_data.csv')

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(data['date_id'],data['target'], label='Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Data')

# Calculate rolling statistics (e.g., moving average)
rolling_mean = data['target'].rolling(window=12).mean()
rolling_std = data['target'].rolling(window=12).std()

# Plot rolling statistics
plt.plot(data['date_id'], rolling_mean, label='Rolling Mean')
plt.plot(data['date_id'], rolling_std, label='Rolling Std')

plt.legend()
plt.show()

# Perform Augmented Dickey-Fuller test
from statsmodels.tsa.stattools import adfuller

result = adfuller(data['target'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])

if result[1] <= 0.05:
    print('The time series is stationary.')
else:
    print('The time series is not stationary.')
# Out:
# ADF Statistic: -25.732757553351526
# p-value: 0.0
# The time series is stationary.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your time series data into a pandas DataFrame
# For example, if your data is in a CSV file, you can use pd.read_csv('your_data.csv')

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(data['time_id'],data['target'], label='Time Series Data')
plt.xlabel('time')
plt.ylabel('Value')
plt.title('Time Series Data')

# Calculate rolling statistics (e.g., moving average)
rolling_mean = data['target'].rolling(window=12).mean()
rolling_std = data['target'].rolling(window=12).std()

# Plot rolling statistics
plt.plot(data['time_id'], rolling_mean, label='Rolling Mean')
plt.plot(data['time_id'], rolling_std, label='Rolling Std')

plt.legend()
plt.show()

# Perform Augmented Dickey-Fuller test
from statsmodels.tsa.stattools import adfuller

result = adfuller(data['target'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])

if result[1] <= 0.05:
    print('The time series is stationary.')
else:
    print('The time series is not stationary.')
# Out:
# ADF Statistic: -25.732757553351526
# p-value: 0.0
# The time series is stationary.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# Load your time series data into a pandas DataFrame
# For example, if your data is in a CSV file, you can use pd.read_csv('your_data.csv')

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(data['time_id'], data['target'], label='Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Data')

# Calculate rolling statistics (e.g., moving average)
rolling_mean = data['target'].rolling(window=12).mean()
rolling_std = data['target'].rolling(window=12).std()

# Plot rolling statistics
plt.plot(data['time_id'], rolling_mean, label='Rolling Mean')
plt.plot(data['time_id'], rolling_std, label='Rolling Std')

plt.legend()
plt.show()

# Perform Augmented Dickey-Fuller test
result = adfuller(data['target'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])

if result[1] <= 0.05:
    print('The time series is stationary.')
else:
    print('The time series is not stationary.')
# Out:
# ADF Statistic: -25.732757553351526
# p-value: 0.0
# The time series is stationary.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller

# Load your time series data into a pandas DataFrame
# Replace 'date_column' and 'value_column' with your own column names
# For example, if your data is in a CSV file, you can use pd.read_csv('your_data.csv')

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(data['time_id'],data['target'], label='Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Data')

# Check for stationarity using ADF test
result = adfuller(data['target'])
if result[1] <= 0.05:
    print('The time series is stationary.')
else:
    print('The time series is not stationary. Please make it stationary before fitting an ARIMA model.')
    # You can use differencing to make it stationary.

# Fit an ARIMA model
# The order of the ARIMA model is represented as (p, d, q), where:
# p: The order of the autoregressive component.
# d: The order of differencing required to make the series stationary.
# q: The order of the moving average component.

# Example: Fit an ARIMA(1, 1, 1) model
p, d, q = 1, 1, 1
model = ARIMA(data['target'], order=(p, d, q))
results = model.fit(disp=-1)

# Print model summary
print(results.summary())

# Plot the fitted values
plt.figure(figsize=(12, 6))
plt.plot(data['time_id'], data['target'], label='Original Data')
plt.plot(data['time_id'], results.fittedvalues, color='red', label='Fitted Values')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('ARIMA Fit')
plt.legend()
plt.show()
# Out:
# The time series is stationary.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-19-be8ee6ae0cf3> in <cell line: 34>()
#      32 # Example: Fit an ARIMA(1, 1, 1) model
#      33 p, d, q = 1, 1, 1
# ---> 34 model = ARIMA(data['target'], order=(p, d, q))
#      35 results = model.fit(disp=-1)
#      36
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# ...
